# %% [markdown]
# We begin by splitting the test data into the class list and attribute lists, and sorting the value-based attribute lists.
#
# |Index|Class|Leaf|
# |-----|-----|----|
# |1|-|N1|
# |2|+|N1|
# |3|-|N1|
# |4|-|N1|
# |5|+|N1|
# |6|-|N1|
# |7|+|N1|
# |8|-|N1|
# |9|+|N1|
# |10|+|N1|
# |11|-|N1|
# |12|+|N1|
#
# |Outlook|Class Index|
# |-------|-----------|
# |Rain|1|
# |Sunny|2|
# |Rain|3|
# |Overcast|4|
# |Sunny|5|
# |Overcast|6|
# |Sunny|7|
# |Sunny|8|
# |Overcast|9|
# |Sunny|10|
# |Sunny|11|
# |Rain|12|
#
# |Temperature|Class Index|
# |-----------|-----------|
# |1|5|
# |2|1|
# |2|4|
# |3|2|
# |3|12|
# |4|3|
# |5|7|
# |6|6|
# |7|10|
# |8|11|
# |9|9|
# |10|8|
#
# |Humidity|Class Index|
# |--------|-----------|
# |2|1|
# |4|5|
# |5|2|
# |6|8|
# |7|4|
# |8|10|
# |10|3|
# |12|7|
# |14|6|
# |16|9|
# |18|11|
# |20|12|

# %% [markdown]
# We start with the attribute outlook and create the histogram using the outlook data:
# N1:
#
# |   |Yes|No|
# |---|---|--|
# |Rain|1|2|
# |Sunny|4|2|
# |Overcast|1|2|
#
# Given this data we calculate the Gini split of the various subsets of outlook: $$Gini_{split}(S, outlook \in \{Rain\}) = Gini_{split}(S, outlook \in \{Overcast\}) = Gini_{split}(S, outlook \in \{Rain, Sunny\}) $$ $$= Gini_{split}(S, outlook \in \{Rain, Sunny\}) = Gini_{split}(S, outlook \in \{Overcast, Sunny\}) = \frac{3}{12}( 1 - (\frac{1}{3})^2 - (\frac{2}{3})^2) + \frac{9}{12}(1 - (\frac{5}{9})^2 - (\frac{4}{9})^2)$$
